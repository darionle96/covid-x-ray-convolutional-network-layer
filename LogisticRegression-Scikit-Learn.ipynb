# %% [markdown]
# **Problem Description**
#
# In this problem, we use scikit-learn to build a logistic regression classifier for the Iris dataset.

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# download Iris data
iris = load_iris(as_frame=True)
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# process the data, only take the first 100 samples.
X = np.array(iris.data)[:100,:2] # only use the first 2 features
y = np.array(iris.target)[:100]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=50, shuffle=True)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50, 2), (50, 2), (50,), (50,))

# %%
#Build Logistic Regression Classifier and fit on training dataset
#Your codes ----------------------------------------------------------

# %%
#Make prediction on the testing dataset
#Your codes ----------------------------------------------------------

# %%
# Evaluate the accuracy
#Your codes ----------------------------------------------------------

print('testing accuracy: ',accuracy)

# %%
# Visualization
fig, ax = plt.subplots(ncols=1, figsize=(10, 5))
ax.scatter(X[:50,0], X[:50,1], label="Train data points")
ax.scatter(X[50:,0], X[50:,1], label="Train data points")
